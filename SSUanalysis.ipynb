# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
import xarray
import numpy as np
import logging

    # Ideally would use ssu, but some diag_tables only saved zos----for coupled waves
pp_root_wave="/archive/Qian.Xiao/Qian.Xiao/FMS_Wave_Coupling_ZC/c5/postProcessing/NWA12.COBALT_wave"
pp_root_all="/archive/Qian.Xiao/Qian.Xiao/FMS_Wave_Coupling_ZC/c5/postProcessing/NWA12.COBALT_all"
pp_root_nolan="/archive/Qian.Xiao/Qian.Xiao/FMS_Wave_Coupling_ZC/c5/postProcessing/NWA12.COBALT_wavenoLan"
pp_root_uncou="/archive/Qian.Xiao/Qian.Xiao/FMS_Wave_Coupling_ZC/c5/postProcessing/NWA12.COBALTuncou"
pp_root_uncou_LAfalse="/archive/Qian.Xiao/Qian.Xiao/FMS_Wave_Coupling_ZC/c5/postProcessing/NWA12.COBALTuncou_LALTFalse"

ocean_daily_wave_1= xarray.open_dataset(pp_root_wave+"/19930101_results/19930101.ocean_daily.nc")
ocean_daily_wave_2= xarray.open_dataset(pp_root_wave+"/19930301_results/19930301.ocean_daily.nc")
ocean_daily_wave_3= xarray.open_dataset(pp_root_wave+"/19930501_results/19930501.ocean_daily.nc")
ocean_daily_wave_4= xarray.open_dataset(pp_root_wave+"/19930701_results/19930701.ocean_daily.nc")
ocean_daily_wave_5= xarray.open_dataset(pp_root_wave+"/19930901_results/19930901.ocean_daily.nc")
ocean_daily_wave_6= xarray.open_dataset(pp_root_wave+"/19931101_results/19931101.ocean_daily.nc")

ocean_daily_all_1= xarray.open_dataset(pp_root_all+"/19930101_results/19930101.ocean_daily.nc")
ocean_daily_all_2= xarray.open_dataset(pp_root_all+"/19930301_results/19930301.ocean_daily.nc")
ocean_daily_all_3= xarray.open_dataset(pp_root_all+"/19930501_results/19930501.ocean_daily.nc")
ocean_daily_all_4= xarray.open_dataset(pp_root_all+"/19930701_results/19930701.ocean_daily.nc")
ocean_daily_all_5= xarray.open_dataset(pp_root_all+"/19930901_results/19930901.ocean_daily.nc")
ocean_daily_all_6= xarray.open_dataset(pp_root_all+"/19931101_results/19931101.ocean_daily.nc")

ocean_daily_nolan_1= xarray.open_dataset(pp_root_nolan+"/19930101_results/19930101.ocean_daily.nc")
ocean_daily_nolan_2= xarray.open_dataset(pp_root_nolan+"/19930301_results/19930301.ocean_daily.nc")
ocean_daily_nolan_3= xarray.open_dataset(pp_root_nolan+"/19930501_results/19930501.ocean_daily.nc")
ocean_daily_nolan_4= xarray.open_dataset(pp_root_nolan+"/19930701_results/19930701.ocean_daily.nc")
ocean_daily_nolan_5= xarray.open_dataset(pp_root_nolan+"/19930901_results/19930901.ocean_daily.nc")
ocean_daily_nolan_6= xarray.open_dataset(pp_root_nolan+"/19931101_results/19931101.ocean_daily.nc")

model_grid_x = ocean_daily_wave_1.variables['xh']
model_grid_y = ocean_daily_wave_1.variables['yh']

ocean_daily_uncou_1= xarray.open_dataset(pp_root_uncou+"/19930101_results/19930101.ocean_daily.nc")
ocean_daily_uncou_2= xarray.open_dataset(pp_root_uncou+"/19930701_results/19930701.ocean_daily.nc")
ocean_daily_uncou_LAfalse_1= xarray.open_dataset(pp_root_uncou_LAfalse+"/19930101_results/19930101.ocean_daily.nc")
ocean_daily_uncou_LAfalse_2= xarray.open_dataset(pp_root_uncou_LAfalse+"/19930701_results/19930701.ocean_daily.nc")
ssu_uncou_1=ocean_daily_uncou_1.variables['ssu']
ssu_uncou_2=ocean_daily_uncou_2.variables['ssu']
xr_ssu_uncou_1= xarray.DataArray(ssu_uncou_1, dims=["time", "yh", "xh"])
xr_ssu_uncou_2= xarray.DataArray(ssu_uncou_2, dims=["time", "yh", "xh"])
ssu_uncou=xarray.concat([xr_ssu_uncou_1, xr_ssu_uncou_2], dim='time')

ssu_uncou_LAfalse_1=ocean_daily_uncou_LAfalse_1.variables['ssu']
ssu_uncou_LAfalse_2=ocean_daily_uncou_LAfalse_2.variables['ssu']
xr_ssu_uncou_LAfalse_1= xarray.DataArray(ssu_uncou_LAfalse_1, dims=["time", "yh", "xh"])
xr_ssu_uncou_LAfalse_2= xarray.DataArray(ssu_uncou_LAfalse_2, dims=["time", "yh", "xh"])
ssu_uncou_LAfalse=xarray.concat([xr_ssu_uncou_LAfalse_1, xr_ssu_uncou_LAfalse_2], dim='time')

ssu_wave_1=ocean_daily_wave_1.variables['ssu']
ssu_wave_2=ocean_daily_wave_2.variables['ssu']
ssu_wave_3=ocean_daily_wave_3.variables['ssu']
ssu_wave_4=ocean_daily_wave_4.variables['ssu']
ssu_wave_5=ocean_daily_wave_5.variables['ssu']
ssu_wave_6=ocean_daily_wave_6.variables['ssu']
xr_ssu_wave_1= xarray.DataArray(ssu_wave_1, dims=["time", "yh", "xh"])
xr_ssu_wave_2= xarray.DataArray(ssu_wave_2, dims=["time", "yh", "xh"])
xr_ssu_wave_3= xarray.DataArray(ssu_wave_3, dims=["time", "yh", "xh"])
xr_ssu_wave_4= xarray.DataArray(ssu_wave_4, dims=["time", "yh", "xh"])
xr_ssu_wave_5= xarray.DataArray(ssu_wave_5, dims=["time", "yh", "xh"])
xr_ssu_wave_6= xarray.DataArray(ssu_wave_6, dims=["time", "yh", "xh"])
ssu_wave=xarray.concat([xr_ssu_wave_1, xr_ssu_wave_2, xr_ssu_wave_3, xr_ssu_wave_4, xr_ssu_wave_5, xr_ssu_wave_6], dim='time')


ssu_all_1=ocean_daily_all_1.variables['ssu']
ssu_all_2=ocean_daily_all_2.variables['ssu']
ssu_all_3=ocean_daily_all_3.variables['ssu']
ssu_all_4=ocean_daily_all_4.variables['ssu']
ssu_all_5=ocean_daily_all_5.variables['ssu']
ssu_all_6=ocean_daily_all_6.variables['ssu']
xr_ssu_all_1= xarray.DataArray(ssu_all_1, dims=["time", "yh", "xh"])
xr_ssu_all_2= xarray.DataArray(ssu_all_2, dims=["time", "yh", "xh"])
xr_ssu_all_3= xarray.DataArray(ssu_all_3, dims=["time", "yh", "xh"])
xr_ssu_all_4= xarray.DataArray(ssu_all_4, dims=["time", "yh", "xh"])
xr_ssu_all_5= xarray.DataArray(ssu_all_5, dims=["time", "yh", "xh"])
xr_ssu_all_6= xarray.DataArray(ssu_all_6, dims=["time", "yh", "xh"])
ssu_all=xarray.concat([xr_ssu_all_1, xr_ssu_all_2, xr_ssu_all_3, xr_ssu_all_4, xr_ssu_all_5, xr_ssu_all_6], dim='time')


ssu_nolan_1=ocean_daily_nolan_1.variables['ssu']
ssu_nolan_2=ocean_daily_nolan_2.variables['ssu']
ssu_nolan_3=ocean_daily_nolan_3.variables['ssu']
ssu_nolan_4=ocean_daily_nolan_4.variables['ssu']
ssu_nolan_5=ocean_daily_nolan_5.variables['ssu']
ssu_nolan_6=ocean_daily_nolan_6.variables['ssu']
xr_ssu_nolan_1= xarray.DataArray(ssu_nolan_1, dims=["time", "yh", "xh"])
xr_ssu_nolan_2= xarray.DataArray(ssu_nolan_2, dims=["time", "yh", "xh"])
xr_ssu_nolan_3= xarray.DataArray(ssu_nolan_3, dims=["time", "yh", "xh"])
xr_ssu_nolan_4= xarray.DataArray(ssu_nolan_4, dims=["time", "yh", "xh"])
xr_ssu_nolan_5= xarray.DataArray(ssu_nolan_5, dims=["time", "yh", "xh"])
xr_ssu_nolan_6= xarray.DataArray(ssu_nolan_6, dims=["time", "yh", "xh"])
ssu_nolan=xarray.concat([xr_ssu_nolan_1, xr_ssu_nolan_2, xr_ssu_nolan_3, xr_ssu_nolan_4, xr_ssu_nolan_5, xr_ssu_nolan_6], dim='time')


ssv_uncou_1=ocean_daily_uncou_1.variables['ssv']
ssv_uncou_2=ocean_daily_uncou_2.variables['ssv']
xr_ssv_uncou_1= xarray.DataArray(ssv_uncou_1, dims=["time", "yh", "xh"])
xr_ssv_uncou_2= xarray.DataArray(ssv_uncou_2, dims=["time", "yh", "xh"])
ssv_uncou=xarray.concat([xr_ssv_uncou_1, xr_ssv_uncou_2], dim='time')

ssv_uncou_LAfalse_1=ocean_daily_uncou_LAfalse_1.variables['ssv']
ssv_uncou_LAfalse_2=ocean_daily_uncou_LAfalse_2.variables['ssv']
xr_ssv_uncou_LAfalse_1= xarray.DataArray(ssv_uncou_LAfalse_1, dims=["time", "yh", "xh"])
xr_ssv_uncou_LAfalse_2= xarray.DataArray(ssv_uncou_LAfalse_2, dims=["time", "yh", "xh"])
ssv_uncou_LAfalse=xarray.concat([xr_ssv_uncou_LAfalse_1, xr_ssv_uncou_LAfalse_2], dim='time')


ssv_wave_1=ocean_daily_wave_1.variables['ssv']
ssv_wave_2=ocean_daily_wave_2.variables['ssv']
ssv_wave_3=ocean_daily_wave_3.variables['ssv']
ssv_wave_4=ocean_daily_wave_4.variables['ssv']
ssv_wave_5=ocean_daily_wave_5.variables['ssv']
ssv_wave_6=ocean_daily_wave_6.variables['ssv']
xr_ssv_wave_1= xarray.DataArray(ssv_wave_1, dims=["time", "yh", "xh"])
xr_ssv_wave_2= xarray.DataArray(ssv_wave_2, dims=["time", "yh", "xh"])
xr_ssv_wave_3= xarray.DataArray(ssv_wave_3, dims=["time", "yh", "xh"])
xr_ssv_wave_4= xarray.DataArray(ssv_wave_4, dims=["time", "yh", "xh"])
xr_ssv_wave_5= xarray.DataArray(ssv_wave_5, dims=["time", "yh", "xh"])
xr_ssv_wave_6= xarray.DataArray(ssv_wave_6, dims=["time", "yh", "xh"])
ssv_wave=xarray.concat([xr_ssv_wave_1, xr_ssv_wave_2, xr_ssv_wave_3, xr_ssv_wave_4, xr_ssv_wave_5, xr_ssv_wave_6], dim='time')


ssv_all_1=ocean_daily_all_1.variables['ssv']
ssv_all_2=ocean_daily_all_2.variables['ssv']
ssv_all_3=ocean_daily_all_3.variables['ssv']
ssv_all_4=ocean_daily_all_4.variables['ssv']
ssv_all_5=ocean_daily_all_5.variables['ssv']
ssv_all_6=ocean_daily_all_6.variables['ssv']
xr_ssv_all_1= xarray.DataArray(ssv_all_1, dims=["time", "yh", "xh"])
xr_ssv_all_2= xarray.DataArray(ssv_all_2, dims=["time", "yh", "xh"])
xr_ssv_all_3= xarray.DataArray(ssv_all_3, dims=["time", "yh", "xh"])
xr_ssv_all_4= xarray.DataArray(ssv_all_4, dims=["time", "yh", "xh"])
xr_ssv_all_5= xarray.DataArray(ssv_all_5, dims=["time", "yh", "xh"])
xr_ssv_all_6= xarray.DataArray(ssv_all_6, dims=["time", "yh", "xh"])
ssv_all=xarray.concat([xr_ssv_all_1, xr_ssv_all_2, xr_ssv_all_3, xr_ssv_all_4, xr_ssv_all_5, xr_ssv_all_6], dim='time')


ssv_nolan_1=ocean_daily_nolan_1.variables['ssv']
ssv_nolan_2=ocean_daily_nolan_2.variables['ssv']
ssv_nolan_3=ocean_daily_nolan_3.variables['ssv']
ssv_nolan_4=ocean_daily_nolan_4.variables['ssv']
ssv_nolan_5=ocean_daily_nolan_5.variables['ssv']
ssv_nolan_6=ocean_daily_nolan_6.variables['ssv']
xr_ssv_nolan_1= xarray.DataArray(ssv_nolan_1, dims=["time", "yh", "xh"])
xr_ssv_nolan_2= xarray.DataArray(ssv_nolan_2, dims=["time", "yh", "xh"])
xr_ssv_nolan_3= xarray.DataArray(ssv_nolan_3, dims=["time", "yh", "xh"])
xr_ssv_nolan_4= xarray.DataArray(ssv_nolan_4, dims=["time", "yh", "xh"])
xr_ssv_nolan_5= xarray.DataArray(ssv_nolan_5, dims=["time", "yh", "xh"])
xr_ssv_nolan_6= xarray.DataArray(ssv_nolan_6, dims=["time", "yh", "xh"])
ssv_nolan=xarray.concat([xr_ssv_nolan_1, xr_ssv_nolan_2, xr_ssv_nolan_3, xr_ssv_nolan_4, xr_ssv_nolan_5, xr_ssv_nolan_6], dim='time')

ssu_wave=ssu_wave[:,:,1:]
ssv_wave=ssv_wave[:,1:,:]
ssu_all=ssu_all[:,:,1:]
ssv_all=ssv_all[:,1:,:]
ssu_nolan=ssu_nolan[:,:,1:]
ssv_nolan=ssv_nolan[:,1:,:]
ssu_uncou=ssu_uncou[:,:,1:]
ssv_uncou=ssv_uncou[:,1:,:]
ssu_uncou_LAfalse=ssu_uncou_LAfalse[:,:,1:]
ssv_uncou_LAfalse=ssv_uncou_LAfalse[:,1:,:]

ss_mag_wave=np.sqrt(ssu_wave**2 + ssv_wave**2)
ss_mag_all=np.sqrt(ssu_all**2 + ssv_all**2)
ss_mag_nolan=np.sqrt(ssu_nolan**2 + ssv_nolan**2)
ss_mag_uncou=np.sqrt(ssu_uncou**2+ ssv_uncou**2)
ss_mag_uncou_LAfalse=np.sqrt(ssu_uncou_LAfalse**2 + ssv_uncou_LAfalse**2)

ss_mag_wave_ave=ss_mag_wave.mean('time')
ss_mag_all_ave=ss_mag_all.mean('time')
ss_mag_nolan_ave=ss_mag_nolan.mean('time')
ss_mag_uncou_ave=ss_mag_uncou.mean('time')
ss_mag_uncou_LAfalse_ave=ss_mag_uncou_LAfalse.mean('time')

plt.figure()
da_ss_mag_wave_ave=xarray.DataArray(ss_mag_wave_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_ss_mag_wave_ave.plot()
plt.title('Reference-wave(LT) with no ME modification ss_mag 1993 annual mean')


plt.figure()
da_ss_mag_all_ave=xarray.DataArray(ss_mag_all_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_ss_mag_all_ave.plot()
plt.title('ME all terms modification ss_mag 1993 annual mean')


plt.figure()
da_ss_mag_nolan_ave=xarray.DataArray(ss_mag_nolan_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_ss_mag_nolan_ave.plot()
plt.title('wave coupled nolangmuire turbulence ss_mag 1993 annual mean')


plt.figure()
da_ss_mag_uncou_ave=xarray.DataArray(ss_mag_uncou_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_ss_mag_uncou_ave.plot()
plt.title('uncoupled ocean model ss_mag 1993 annual mean')

plt.figure()
da_ss_mag_uncou_LAfalse_ave=xarray.DataArray(ss_mag_uncou_LAfalse_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_ss_mag_uncou_LAfalse_ave.plot()
plt.title('uncoupled ocean model with no langmuire turbulence ss_mag 1993 annual mean')

diff_ss_mag_all_ave= ss_mag_all_ave - ss_mag_wave_ave
plt.figure()
da_diff_ss_mag_all_ave=xarray.DataArray(diff_ss_mag_all_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_diff_ss_mag_all_ave.plot()
plt.title('All terms with ME modification - wave ss_mag 1993 annual mean')
plt.show()

diff_ss_mag_nolan_ave= ss_mag_nolan_ave - ss_mag_wave_ave
plt.figure()
da_diff_ss_mag_nolan_ave=xarray.DataArray(diff_ss_mag_nolan_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_diff_ss_mag_nolan_ave.plot()
plt.title('nolan - wave ss_mag 1993 annual mean')
plt.show()

diff_ss_mag_ocean_ave= ss_mag_uncou_ave - ss_mag_wave_ave
plt.figure()
da_diff_ss_mag_ocean_ave=xarray.DataArray(diff_ss_mag_ocean_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_diff_ss_mag_ocean_ave.plot()
plt.title('uncoupled ocean model - wave ss_mag 1993 annual mean')
plt.show()

diff_ss_mag_oceanLA_ave= ss_mag_uncou_LAfalse_ave - ss_mag_uncou_ave
plt.figure()
da_diff_ss_mag_oceanLA_ave=xarray.DataArray(diff_ss_mag_oceanLA_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_diff_ss_mag_oceanLA_ave.plot()
plt.title('uncoupled ocean model with no langmuire turbulence - uncoupled ocean model ss_mag 1993 annual mean')
plt.show()
