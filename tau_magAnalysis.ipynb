# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
import xarray
import numpy as np
import logging

    # Ideally would use taux, but some diag_tables only saved zos----for coupled waves
pp_root_wave="/archive/Qian.Xiao/Qian.Xiao/FMS_Wave_Coupling_ZC/c5/postProcessing/NWA12.COBALT_wave"
pp_root_all="/archive/Qian.Xiao/Qian.Xiao/FMS_Wave_Coupling_ZC/c5/postProcessing/NWA12.COBALT_all"
pp_root_nolan="/archive/Qian.Xiao/Qian.Xiao/FMS_Wave_Coupling_ZC/c5/postProcessing/NWA12.COBALT_wavenoLan"

ocean_daily_wave_1= xarray.open_dataset(pp_root_wave+"/19930101_results/19930101.ocean_daily.nc")
ocean_daily_wave_2= xarray.open_dataset(pp_root_wave+"/19930301_results/19930301.ocean_daily.nc")
ocean_daily_wave_3= xarray.open_dataset(pp_root_wave+"/19930501_results/19930501.ocean_daily.nc")
ocean_daily_wave_4= xarray.open_dataset(pp_root_wave+"/19930701_results/19930701.ocean_daily.nc")
ocean_daily_wave_5= xarray.open_dataset(pp_root_wave+"/19930901_results/19930901.ocean_daily.nc")
ocean_daily_wave_6= xarray.open_dataset(pp_root_wave+"/19931101_results/19931101.ocean_daily.nc")

ocean_daily_all_1= xarray.open_dataset(pp_root_all+"/19930101_results/19930101.ocean_daily.nc")
ocean_daily_all_2= xarray.open_dataset(pp_root_all+"/19930301_results/19930301.ocean_daily.nc")
ocean_daily_all_3= xarray.open_dataset(pp_root_all+"/19930501_results/19930501.ocean_daily.nc")
ocean_daily_all_4= xarray.open_dataset(pp_root_all+"/19930701_results/19930701.ocean_daily.nc")
ocean_daily_all_5= xarray.open_dataset(pp_root_all+"/19930901_results/19930901.ocean_daily.nc")
ocean_daily_all_6= xarray.open_dataset(pp_root_all+"/19931101_results/19931101.ocean_daily.nc")

ocean_daily_nolan_1= xarray.open_dataset(pp_root_nolan+"/19930101_results/19930101.ocean_daily.nc")
ocean_daily_nolan_2= xarray.open_dataset(pp_root_nolan+"/19930301_results/19930301.ocean_daily.nc")
ocean_daily_nolan_3= xarray.open_dataset(pp_root_nolan+"/19930501_results/19930501.ocean_daily.nc")
ocean_daily_nolan_4= xarray.open_dataset(pp_root_nolan+"/19930701_results/19930701.ocean_daily.nc")
ocean_daily_nolan_5= xarray.open_dataset(pp_root_nolan+"/19930901_results/19930901.ocean_daily.nc")
ocean_daily_nolan_6= xarray.open_dataset(pp_root_nolan+"/19931101_results/19931101.ocean_daily.nc")

model_grid_x = ocean_daily_wave_1.variables['xh']
model_grid_y = ocean_daily_wave_1.variables['yh']

taux_wave_1=ocean_daily_wave_1.variables['taux']
taux_wave_2=ocean_daily_wave_2.variables['taux']
taux_wave_3=ocean_daily_wave_3.variables['taux']
taux_wave_4=ocean_daily_wave_4.variables['taux']
taux_wave_5=ocean_daily_wave_5.variables['taux']
taux_wave_6=ocean_daily_wave_6.variables['taux']
xr_taux_wave_1= xarray.DataArray(taux_wave_1, dims=["time", "yh", "xh"])
xr_taux_wave_2= xarray.DataArray(taux_wave_2, dims=["time", "yh", "xh"])
xr_taux_wave_3= xarray.DataArray(taux_wave_3, dims=["time", "yh", "xh"])
xr_taux_wave_4= xarray.DataArray(taux_wave_4, dims=["time", "yh", "xh"])
xr_taux_wave_5= xarray.DataArray(taux_wave_5, dims=["time", "yh", "xh"])
xr_taux_wave_6= xarray.DataArray(taux_wave_6, dims=["time", "yh", "xh"])
taux_wave=xarray.concat([xr_taux_wave_1, xr_taux_wave_2, xr_taux_wave_3, xr_taux_wave_4, xr_taux_wave_5, xr_taux_wave_6], dim='time')
taux_wave_ave=taux_wave.mean('time')

# taux_wave_ave_1 = xarray.DataArray(taux_wave_1.mean('time')[:,1:], dims=["yh", "xh"])
# taux_wave_ave_2 = xarray.DataArray(taux_wave_2.mean('time')[:,1:], dims=["yh", "xh"])
# taux_wave_ave_3 = xarray.DataArray(taux_wave_3.mean('time')[:,1:], dims=["yh", "xh"])
# taux_wave_ave_4 = xarray.DataArray(taux_wave_4.mean('time')[:,1:], dims=["yh", "xh"])
# taux_wave_ave_5 = xarray.DataArray(taux_wave_5.mean('time')[:,1:], dims=["yh", "xh"])
# taux_wave_ave_6 = xarray.DataArray(taux_wave_6.mean('time')[:,1:], dims=["yh", "xh"])

taux_all_1=ocean_daily_all_1.variables['taux']
taux_all_2=ocean_daily_all_2.variables['taux']
taux_all_3=ocean_daily_all_3.variables['taux']
taux_all_4=ocean_daily_all_4.variables['taux']
taux_all_5=ocean_daily_all_5.variables['taux']
taux_all_6=ocean_daily_all_6.variables['taux']
xr_taux_all_1= xarray.DataArray(taux_all_1, dims=["time", "yh", "xh"])
xr_taux_all_2= xarray.DataArray(taux_all_2, dims=["time", "yh", "xh"])
xr_taux_all_3= xarray.DataArray(taux_all_3, dims=["time", "yh", "xh"])
xr_taux_all_4= xarray.DataArray(taux_all_4, dims=["time", "yh", "xh"])
xr_taux_all_5= xarray.DataArray(taux_all_5, dims=["time", "yh", "xh"])
xr_taux_all_6= xarray.DataArray(taux_all_6, dims=["time", "yh", "xh"])
taux_all=xarray.concat([xr_taux_all_1, xr_taux_all_2, xr_taux_all_3, xr_taux_all_4, xr_taux_all_5, xr_taux_all_6], dim='time')
taux_all_ave=taux_all.mean('time')
# taux_all_ave_1 = xarray.DataArray(taux_all_1.mean('time')[:,1:], dims=["yh", "xh"])
# taux_all_ave_2 = xarray.DataArray(taux_all_2.mean('time')[:,1:], dims=["yh", "xh"])
# taux_all_ave_3 = xarray.DataArray(taux_all_3.mean('time')[:,1:], dims=["yh", "xh"])
# taux_all_ave_4 = xarray.DataArray(taux_all_4.mean('time')[:,1:], dims=["yh", "xh"])
# taux_all_ave_5 = xarray.DataArray(taux_all_5.mean('time')[:,1:], dims=["yh", "xh"])
# taux_all_ave_6 = xarray.DataArray(taux_all_6.mean('time')[:,1:], dims=["yh", "xh"])


taux_nolan_1=ocean_daily_nolan_1.variables['taux']
taux_nolan_2=ocean_daily_nolan_2.variables['taux']
taux_nolan_3=ocean_daily_nolan_3.variables['taux']
taux_nolan_4=ocean_daily_nolan_4.variables['taux']
taux_nolan_5=ocean_daily_nolan_5.variables['taux']
taux_nolan_6=ocean_daily_nolan_6.variables['taux']
xr_taux_nolan_1= xarray.DataArray(taux_nolan_1, dims=["time", "yh", "xh"])
xr_taux_nolan_2= xarray.DataArray(taux_nolan_2, dims=["time", "yh", "xh"])
xr_taux_nolan_3= xarray.DataArray(taux_nolan_3, dims=["time", "yh", "xh"])
xr_taux_nolan_4= xarray.DataArray(taux_nolan_4, dims=["time", "yh", "xh"])
xr_taux_nolan_5= xarray.DataArray(taux_nolan_5, dims=["time", "yh", "xh"])
xr_taux_nolan_6= xarray.DataArray(taux_nolan_6, dims=["time", "yh", "xh"])
taux_nolan=xarray.concat([xr_taux_nolan_1, xr_taux_nolan_2, xr_taux_nolan_3, xr_taux_nolan_4, xr_taux_nolan_5, xr_taux_nolan_6], dim='time')
taux_nolan_ave=taux_nolan.mean('time')
# taux_nolan_ave_1 = xarray.DataArray(taux_nolan_1.mean('time')[:,1:], dims=["yh", "xh"])
# taux_nolan_ave_2 = xarray.DataArray(taux_nolan_2.mean('time')[:,1:], dims=["yh", "xh"])
# taux_nolan_ave_3 = xarray.DataArray(taux_nolan_3.mean('time')[:,1:], dims=["yh", "xh"])
# taux_nolan_ave_4 = xarray.DataArray(taux_nolan_4.mean('time')[:,1:], dims=["yh", "xh"])
# taux_nolan_ave_5 = xarray.DataArray(taux_nolan_5.mean('time')[:,1:], dims=["yh", "xh"])
# taux_nolan_ave_6 = xarray.DataArray(taux_nolan_6.mean('time')[:,1:], dims=["yh", "xh"])

tauy_wave_1=ocean_daily_wave_1.variables['tauy']
tauy_wave_2=ocean_daily_wave_2.variables['tauy']
tauy_wave_3=ocean_daily_wave_3.variables['tauy']
tauy_wave_4=ocean_daily_wave_4.variables['tauy']
tauy_wave_5=ocean_daily_wave_5.variables['tauy']
tauy_wave_6=ocean_daily_wave_6.variables['tauy']
xr_tauy_wave_1= xarray.DataArray(tauy_wave_1, dims=["time", "yh", "xh"])
xr_tauy_wave_2= xarray.DataArray(tauy_wave_2, dims=["time", "yh", "xh"])
xr_tauy_wave_3= xarray.DataArray(tauy_wave_3, dims=["time", "yh", "xh"])
xr_tauy_wave_4= xarray.DataArray(tauy_wave_4, dims=["time", "yh", "xh"])
xr_tauy_wave_5= xarray.DataArray(tauy_wave_5, dims=["time", "yh", "xh"])
xr_tauy_wave_6= xarray.DataArray(tauy_wave_6, dims=["time", "yh", "xh"])
tauy_wave=xarray.concat([xr_tauy_wave_1, xr_tauy_wave_2, xr_tauy_wave_3, xr_tauy_wave_4, xr_tauy_wave_5, xr_tauy_wave_6], dim='time')
# tauy_wave_ave=tauy_wave.mean('time')

tauy_all_1=ocean_daily_all_1.variables['tauy']
tauy_all_2=ocean_daily_all_2.variables['tauy']
tauy_all_3=ocean_daily_all_3.variables['tauy']
tauy_all_4=ocean_daily_all_4.variables['tauy']
tauy_all_5=ocean_daily_all_5.variables['tauy']
tauy_all_6=ocean_daily_all_6.variables['tauy']
xr_tauy_all_1= xarray.DataArray(tauy_all_1, dims=["time", "yh", "xh"])
xr_tauy_all_2= xarray.DataArray(tauy_all_2, dims=["time", "yh", "xh"])
xr_tauy_all_3= xarray.DataArray(tauy_all_3, dims=["time", "yh", "xh"])
xr_tauy_all_4= xarray.DataArray(tauy_all_4, dims=["time", "yh", "xh"])
xr_tauy_all_5= xarray.DataArray(tauy_all_5, dims=["time", "yh", "xh"])
xr_tauy_all_6= xarray.DataArray(tauy_all_6, dims=["time", "yh", "xh"])
tauy_all=xarray.concat([xr_tauy_all_1, xr_tauy_all_2, xr_tauy_all_3, xr_tauy_all_4, xr_tauy_all_5, xr_tauy_all_6], dim='time')
# tauy_all_ave=tauy_all.mean('time')

tauy_nolan_1=ocean_daily_nolan_1.variables['tauy']
tauy_nolan_2=ocean_daily_nolan_2.variables['tauy']
tauy_nolan_3=ocean_daily_nolan_3.variables['tauy']
tauy_nolan_4=ocean_daily_nolan_4.variables['tauy']
tauy_nolan_5=ocean_daily_nolan_5.variables['tauy']
tauy_nolan_6=ocean_daily_nolan_6.variables['tauy']
xr_tauy_nolan_1= xarray.DataArray(tauy_nolan_1, dims=["time", "yh", "xh"])
xr_tauy_nolan_2= xarray.DataArray(tauy_nolan_2, dims=["time", "yh", "xh"])
xr_tauy_nolan_3= xarray.DataArray(tauy_nolan_3, dims=["time", "yh", "xh"])
xr_tauy_nolan_4= xarray.DataArray(tauy_nolan_4, dims=["time", "yh", "xh"])
xr_tauy_nolan_5= xarray.DataArray(tauy_nolan_5, dims=["time", "yh", "xh"])
xr_tauy_nolan_6= xarray.DataArray(tauy_nolan_6, dims=["time", "yh", "xh"])
tauy_nolan=xarray.concat([xr_tauy_nolan_1, xr_tauy_nolan_2, xr_tauy_nolan_3, xr_tauy_nolan_4, xr_tauy_nolan_5, xr_tauy_nolan_6], dim='time')
# tauy_nolan_ave=tauy_nolan.mean('time')
taux_wave=taux_wave[:,:,1:]
tauy_wave=tauy_wave[:,1:,:]
taux_all=taux_all[:,:,1:]
tauy_all=tauy_all[:,1:,:]
taux_nolan=taux_nolan[:,:,1:]
tauy_nolan=tauy_nolan[:,1:,:]

tau_mag_wave=np.sqrt(taux_wave**2 + tauy_wave**2)
tau_mag_all=np.sqrt(taux_all**2 + tauy_all**2)
tau_mag_nolan=np.sqrt(taux_nolan**2 + tauy_nolan**2)

tau_mag_wave_ave=tau_mag_wave.mean('time')
tau_mag_all_ave=tau_mag_all.mean('time')
tau_mag_nolan_ave=tau_mag_nolan.mean('time')

plt.figure()
da_tau_mag_wave_ave=xarray.DataArray(tau_mag_wave_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_tau_mag_wave_ave.plot()
plt.title('Reference-wave(LT) with no ME modification tau_mag 1993 annual mean')

diff_tau_mag_all_ave= tau_mag_all_ave - tau_mag_wave_ave
plt.figure()
da_diff_tau_mag_all_ave=xarray.DataArray(diff_tau_mag_all_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_diff_tau_mag_all_ave.plot()
plt.title('All terms with ME modification - wave tau_mag 1993 annual mean')
plt.show()

diff_tau_mag_nolan_ave= tau_mag_nolan_ave - tau_mag_wave_ave
plt.figure()
da_diff_tau_mag_nolan_ave=xarray.DataArray(diff_tau_mag_nolan_ave, dims=['yh', 'xh'], coords={'xh': model_grid_x, 'yh': model_grid_y})
da_diff_tau_mag_nolan_ave.plot()
plt.title('nolan - wave tau_mag 1993 annual mean')
plt.show()

# %%
ocean_daily_wave_1
# Out:
# <xarray.Dataset>
# Dimensions:           (xh: 775, yh: 845, zl: 75, time: 59, nv: 2, xq: 776,
#                        yq: 846, zi: 76)
# Coordinates:
#   * xh                (xh) float64 -98.0 -97.92 -97.84 ... -36.24 -36.16 -36.08
#   * yh                (yh) float64 5.273 5.352 5.432 5.511 ... 51.9 51.91 51.93
#   * zl                (zl) float64 1.0 3.0 5.0 ... 5.875e+03 6.125e+03 6.375e+03
#   * time              (time) datetime64[ns] 1993-01-01T12:00:00 ... 1993-02-2...
#   * nv                (nv) float64 1.0 2.0
#   * xq                (xq) float64 -98.04 -97.96 -97.88 ... -36.2 -36.12 -36.04
#   * yq                (yq) float64 5.233 5.312 5.392 5.472 ... 51.9 51.92 51.94
#   * zi                (zi) float64 0.0 2.0 4.0 6.0 ... 6e+03 6.25e+03 6.5e+03
# Data variables: (12/39)
#     volcello          (time, zl, yh, xh) float32 ...
#     ssh               (time, yh, xh) float32 ...
#     sshmin            (time, yh, xh) float32 ...
# ...
