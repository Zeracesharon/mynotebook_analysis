# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
import xarray 
import numpy as np
import logging
from netCDF4 import Dataset


hgrid_path="/gpfs/f5/gfdl_o/scratch/Qian.Xiao/FMS_Wave_Coupling_ZC/examples/NWA12.COBALT_all_wave1_6/INPUT/EXCHANGE_GRIDS/wave_hgrid.nc"
topo_path="/gpfs/f5/gfdl_o/scratch/Qian.Xiao/FMS_Wave_Coupling_ZC/examples/NWA12.COBALT_all_wave1_6/INPUT/EXCHANGE_GRIDS/wave_topoghalf.nc"
ds_hgrid= xarray.open_dataset(hgrid_path)
ds_topo=xarray.open_dataset(topo_path)

print(ds_hgrid)  # Prints the variables, dimensions, and metadata
print(ds_topo)
# Out:
# <xarray.Dataset>
# Dimensions:   (nyp: 1691, nxp: 1551, nx: 1550, ny: 1690)
# Dimensions without coordinates: nyp, nxp, nx, ny
# Data variables:
#     x         (nyp, nxp) float64 ...
#     y         (nyp, nxp) float64 ...
#     angle_dx  (nyp, nxp) float64 ...
#     dx        (nyp, nx) float64 ...
#     dy        (ny, nxp) float64 ...
#     area      (ny, nx) float64 ...
#     tile      |S255 ...
# Attributes:
#     history:  grid_hycom2mom6
# <xarray.Dataset>
# Dimensions:  (ntiles: 1, ny: 845, nx: 775)
# Coordinates:
#   * ntiles   (ntiles) int32 1
# Dimensions without coordinates: ny, nx
# Data variables:
#     depth    (ny, nx) float32 ...
# Attributes:
#     grid_version:              0.2
#     code_version:              ESMG/gridtools: ['heads/main-0-gea88375397', '']
#     history:                   Thu Jan 13 17:05:42 2022: ncap2 -s defdim("nti...
#     NCO:                       "4.5.4"
#     nco_openmp_thread_number:  1

# %%
ds_hgrid
# Out:
# <xarray.Dataset>
# Dimensions:   (nyp: 1691, nxp: 1551, nx: 1550, ny: 1690)
# Dimensions without coordinates: nyp, nxp, nx, ny
# Data variables:
#     x         (nyp, nxp) float64 ...
#     y         (nyp, nxp) float64 ...
#     angle_dx  (nyp, nxp) float64 ...
#     dx        (nyp, nx) float64 ...
#     dy        (ny, nxp) float64 ...
#     area      (ny, nx) float64 ...
#     tile      |S255 ...
# Attributes:
#     history:  grid_hycom2mom6

# %%
ds_topo
# Out:
# <xarray.Dataset>
# Dimensions:  (ntiles: 1, ny: 845, nx: 775)
# Coordinates:
#   * ntiles   (ntiles) int32 1
# Dimensions without coordinates: ny, nx
# Data variables:
#     depth    (ny, nx) float32 ...
# Attributes:
#     grid_version:              0.2
#     code_version:              ESMG/gridtools: ['heads/main-0-gea88375397', '']
#     history:                   Thu Jan 13 17:05:42 2022: ncap2 -s defdim("nti...
#     NCO:                       "4.5.4"
#     nco_openmp_thread_number:  1

# %%
# downsampled_ds = ds_hgrid.isel(nyp=slice(None, None, 2), nxp=slice(None, None, 2))

# # If needed, downsample dimensions like 'ny' and 'nx' as well
# if 'ny' in ds_hgrid.dims:
#     downsampled_ds = downsampled_ds.isel(ny=slice(None, None, 2))
# if 'nx' in ds_hgrid.dims:
#     downsampled_ds = downsampled_ds.isel(nx=slice(None, None, 2))

# # Step 3: Save the downsampled data into a new NetCDF file
# output_path = '/gpfs/f5/gfdl_o/scratch/Qian.Xiao/FMS_Wave_Coupling_ZC/examples/NWA12.COBALT_all/INPUT/EXCHANGE_GRIDS/ocean_hgrid_downsampled.nc'
# downsampled_ds.to_netcdf(output_path)
# print(f"Downsampled grid saved to {output_path}")

# Truncate dimensions to ensure even values before downsampling
# nyp_truncated = 845 * 2
# nxp_truncated = 775 * 2
# ny_truncated = 844 * 2
# nx_truncated = 774 * 2

# # Downsample the dataset
# downsampled_ds_hgrid = ds_hgrid.isel(
#     nyp=slice(0, nyp_truncated, 2),
#     nxp=slice(0, nxp_truncated, 2),
#     ny=slice(0, ny_truncated, 2),
#     nx=slice(0, nx_truncated, 2)
# )

downsampled_ds_hgrid = ds_hgrid.isel(nyp=slice(None, None, 2), nxp=slice(None, None, 2))

# If needed, downsample dimensions like 'ny' and 'nx' as well
if 'ny' in ds_hgrid.dims:
    downsampled_ds_hgrid = downsampled_ds_hgrid.isel(ny=slice(None, None, 2))
if 'nx' in ds_hgrid.dims:
    downsampled_ds_hgrid = downsampled_ds_hgrid.isel(nx=slice(None, None, 2))


# Save the downsampled dataset to a new NetCDF file
output_file='/gpfs/f5/gfdl_o/scratch/Qian.Xiao/FMS_Wave_Coupling_ZC/examples/NWA12.COBALT_all_wave1_6/INPUT/EXCHANGE_GRIDS/wave_hgrid_gene.nc'
downsampled_ds_hgrid.to_netcdf(output_file)

print(f"Downsampled dataset saved to {output_file}")

# downsampled_ds_topo = ds_topo.isel(ny=slice(None, None, 2), nx=slice(None, None, 2))

# # Step 3: Save the downsampled data into a new NetCDF file
# output_path = '/gpfs/f5/gfdl_o/scratch/Qian.Xiao/FMS_Wave_Coupling_ZC/examples/NWA12.COBALT_all/INPUT/EXCHANGE_GRIDS/ocean_topo_downsampled.nc'
# downsampled_ds_topo.to_netcdf(output_path)

# print(f"Downsampled file saved to {output_path}")
# downsampled_ds_topo


# ds_trimmed_topo = ds_topo.isel(
#     ny=slice(0, ds_topo.dims['ny'] - (ds_topo.dims['ny'] % 2)),  # Ensure 'ny' is even
#     nx=slice(0, ds_topo.dims['nx'] - (ds_topo.dims['nx'] % 2))   # Ensure 'nx' is even
# )

# # Downsample by selecting every other point
# downsampled_ds_topo = ds_trimmed_topo.isel(
#     ny=slice(0, None, 2),  # Take every second point along 'ny'
#     nx=slice(0, None, 2)   # Take every second point along 'nx'
# )

downsampled_ds_topo = ds_topo.isel(ny=slice(None, None, 2), nx=slice(None, None, 2))
output_file="/gpfs/f5/gfdl_o/scratch/Qian.Xiao/FMS_Wave_Coupling_ZC/examples/NWA12.COBALT_all_wave1_6/INPUT/EXCHANGE_GRIDS/wave_topog_gene.nc"
# Save the downsampled dataset to a new NetCDF file
downsampled_ds_topo.to_netcdf(output_file)
downsampled_ds_topo
print(f"Downsampled dataset saved to {output_file}")
# Out:
# Downsampled dataset saved to /gpfs/f5/gfdl_o/scratch/Qian.Xiao/FMS_Wave_Coupling_ZC/examples/NWA12.COBALT_all_wave1_6/INPUT/EXCHANGE_GRIDS/wave_hgrid_gene.nc
# Downsampled dataset saved to /gpfs/f5/gfdl_o/scratch/Qian.Xiao/FMS_Wave_Coupling_ZC/examples/NWA12.COBALT_all_wave1_6/INPUT/EXCHANGE_GRIDS/wave_topog_gene.nc

# %%
downsampled_ds_topo
# Out:
# <xarray.Dataset>
# Dimensions:  (ntiles: 1, ny: 423, nx: 388)
# Coordinates:
#   * ntiles   (ntiles) int32 1
# Dimensions without coordinates: ny, nx
# Data variables:
#     depth    (ny, nx) float32 ...
# Attributes:
#     grid_version:              0.2
#     code_version:              ESMG/gridtools: ['heads/main-0-gea88375397', '']
#     history:                   Thu Jan 13 17:05:42 2022: ncap2 -s defdim("nti...
#     NCO:                       "4.5.4"
#     nco_openmp_thread_number:  1

# %%
downsampled_ds_hgrid
# Out:
# <xarray.Dataset>
# Dimensions:   (nyp: 846, nxp: 776, nx: 775, ny: 845)
# Dimensions without coordinates: nyp, nxp, nx, ny
# Data variables:
#     x         (nyp, nxp) float64 ...
#     y         (nyp, nxp) float64 ...
#     angle_dx  (nyp, nxp) float64 ...
#     dx        (nyp, nx) float64 ...
#     dy        (ny, nxp) float64 ...
#     area      (ny, nx) float64 ...
#     tile      |S255 ...
# Attributes:
#     history:  grid_hycom2mom6
